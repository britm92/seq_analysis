# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

# %%
TS_rpkm=pd.read_csv('2018-05-22_RNAseq/TS_rpkm.csv',index_col=0)
NTS_rpkm=pd.read_csv('2018-05-22_RNAseq/NTS_rpkm.csv',index_col=0)
joined=TS_rpkm.join(NTS_rpkm)

# %%
TSS=pd.read_csv('primary_upstreamsense_TSS_2',sep='\t',header=None)

# %%
TSS
# Out:
#                 0        1        2     3     4  5
# 0     NC_000913.2     2081     3081  gene  thrB  +
# 1     NC_000913.2     4647     5647  gene  yaaX  +
# 2     NC_000913.2    11436    12436  gene  yaaI  -
# 3     NC_000913.2    16449    17449  gene  hokC  -
# 4     NC_000913.2    16452    17452  gene  sokC  +
# ...           ...      ...      ...   ...   ... ..
# 1859  NC_000913.2  4631295  4632295  gene  yjjX  -
# 1860  NC_000913.2  4632766  4633766  gene  creA  +
# 1861  NC_000913.2  4632876  4633876  gene   rob  -
# 1862  NC_000913.2  4633247  4634247  gene  creB  +
# 1863  NC_000913.2  4637895  4638895  gene  arcA  -
#
# [1864 rows x 6 columns]

# %%
TSS.columns=['ref','start','end','-','Gene name','strand']

# %%
TSS=TSS.set_index('Gene name')

# %%
joined
# Out:
#               bm01_TS     bm05_TS     bm08_TS     bm03_TS     bm12_TS  \
# Gene name
# aaeA         2.162515    1.781870    2.540917    2.579440    2.650139
# aaeB         2.844519    2.350746    2.227275    3.522769    1.912503
# aaeR        10.102740    9.288636    8.565052    5.898592    6.094553
# aaeX         1.037295    0.641632    0.699941    1.567396    1.684681
# aas         16.733650   14.237742   18.251859   12.428580   11.369756
# ...               ...         ...         ...         ...         ...
# zraR        26.517176   23.346915   22.090676   18.117000   13.765647
# zraS        19.508870   19.066837   20.884338   15.006889   13.790589
# zupT        80.554752   68.959000   64.518653   57.397982   46.552366
# zur         73.071899   57.917527   67.641287   58.213139   38.294059
# zwf        190.523327  141.245293  179.897969  166.389142  186.851649
#
#               bm10_TS     bm02_TS     bm06_TS     bm09_TS     bm04_TS  ...  \
# ...

# %%
TSS_joined=TSS.join(joined).dropna()

# %%
TSS_filtered=TSS_joined[(TSS_joined['bm03_TS']>20) & (TSS_joined['bm03_TS']<100)]

# %%
TSS_filtered
# Out:
#                    ref    start      end     - strand    bm01_TS     bm05_TS  \
# Gene name
# ackA       NC_000913.2  2410769  2411769  gene      +  80.033960   90.130151
# acnA       NC_000913.2  1333305  1334305  gene      +  20.050623   21.022788
# acpT       NC_000913.2  3610462  3611462  gene      +  24.444468   24.408233
# acrA       NC_000913.2   484564   485564  gene      -  62.760265   50.140710
# alaA       NC_000913.2  2405031  2406031  gene      +  22.666218   23.064203
# ...                ...      ...      ...   ...    ...        ...         ...
# zapC       NC_000913.2  1004576  1005576  gene      +  86.692606  112.527911
# zapD       NC_000913.2   112188   113188  gene      -  25.668516   30.765931
# znuA       NC_000913.2  1940136  1941136  gene      -  54.934346   78.856485
# zupT       NC_000913.2  3179946  3180946  gene      +  80.554752   68.959000
# zur        NC_000913.2  4257554  4258554  gene      -  73.071899   57.917527
#
# ...

# %%
TSS.to_csv('TSS_mid_transcribed')
